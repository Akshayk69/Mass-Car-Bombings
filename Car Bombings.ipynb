# %%
import pandas as pd
from tqdm import tqdm
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %%
browser=webdriver.Firefox()

# %%
url='https://en.wikipedia.org/wiki/List_of_mass_car_bombings'

# %%
browser.get(url)

# %%
html=browser.page_source

# %%
soup=BeautifulSoup(html,'lxml')

# %%
soup.title.text
# Out:
# 'List of mass car bombings - Wikipedia'

# %%
table1=soup.select('table.wikitable.sortable.jquery-tablesorter')[0]
table1
# Out:
# <table class="wikitable sortable jquery-tablesorter">
# <thead><tr>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Year</th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Date</th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Country</th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">City</th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Deaths</th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">Type</th>
# <th class="headerSort" role="columnheader button" tabindex="0" title="Sort ascending">More info
# </th></tr></thead><tbody>
# <tr>
# <td><b>2020</b>
# </td>
# <td>April 28
# </td>
# ...

# %%
table1.find_all('th')[0].text
# Out:
# 'Year'

# %%
column_name=[i.text for i in table1.find_all('th')]
column_name
# Out:
# ['Year', 'Date', 'Country', 'City', 'Deaths', 'Type', 'More info\n']

# %%
def wiki_table():
    thead = [i.text.strip() for i in table.find_all('th')]
    data=[]
    for r in table.tbody.find_all('tr'):
        data.append([i.text.strip() for i in r.find_all('td')])
    df = pd.DataFrame(data)
    df.columns = thead
    return df

# %%
tables=[]
for i in tqdm(range(0,7)):
    table=soup.select('table.wikitable.sortable.jquery-tablesorter')[i]
    tables.append(wiki_table())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 13.61it/s]

# %%
attacks=pd.concat(tables,axis=0)

# %%
attacks.to_csv('Car_Bombings.csv')

# %%
pd.read_csv('Car_Bombings.csv')
# Out:
#      Unnamed: 0    Year          Date                        Country  \
# 0             0  2020.0      April 28                          Syria
# 1             1  2021.0       March 5                        Somalia
# 2             2     NaN      April 21                       Pakistan
# 3             3     NaN         May 8                    Afghanistan
# 4             4     NaN  September 25                        Somalia
# ..          ...     ...           ...                            ...
# 322           5     NaN           NaN  British Mandate for Palestine
# 323           6     NaN           NaN  British Mandate for Palestine
# 324           7     NaN           NaN  British Mandate for Palestine
# 325           8     NaN           NaN                  United States
# 326           9     NaN           NaN                  United States
#
#           City Deaths              Type  \
# 0        Afrin     53        truck bomb
# 1    Mogadishu     21          car bomb
# ...
